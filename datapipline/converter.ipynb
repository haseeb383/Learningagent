# %%
# ! nvidia-smi
! pip install -U uv
! uv pip install --system pypdf "mineru[all]" docling marker-pdf vllm

import os
from pdf_converters import convert_with_marker, INPUT_DIR, OUTPUT_DIR
from google.colab import drive
drive.mount('/content/drive')
input_file_name = "test_snippet.pdf"

if __name__ == "__main__":
    os.makedirs(INPUT_DIR, exist_ok=True)
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    convert_with_marker("test_snippet.pdf")
