# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! pip install -q -U qwen-vl-utils[decord]
! pip install -q -U langgraph langchain-core
! pip install -q -U pymupdf pillow

# %%
! pip install -q -U git+https://github.com/huggingface/transformers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# Upload chunker_agent.py and instructions.md into the SAME folder in Colab
# (e.g. /content/pastpaper_agent/) — either drag them into the Colab file
# browser, or put them in Drive and copy them into /content/.

import sys
sys.path.insert(0, "/content")

from chunker_agent import load_model
load_model()   # downloads + loads Qwen2.5-VL-7B-Instruct in 4-bit, ~2-4 min first time
# Out:
# ...
# Loading Qwen/Qwen2.5-VL-7B-Instruct in 4-bit... (first time will download ~5-8GB)
# /usr/local/lib/python3.13/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_5564/4245766485.py in <cell line: 0>()
#       7
#       8 from chunker_agent import load_model
# ----> 9 load_model()   # downloads + loads Qwen2.5-VL-7B-Instruct in 4-bit, ~2-4 min first time
#
# /content/chunker_agent.py in load_model()
#      36
#      37     print(f"Loading {MODEL_ID} in 4-bit... (first time will download ~5-8GB)")
# ...

# %%
from chunker_agent import run_pipeline

metadata = run_pipeline(
    pdf_path="/content/drive/MyDrive/learningagentpastpapers/9709_m26_qp_42.pdf",
    output_root="/content/drive/MyDrive/learningagentpastpapers",
    window_size=3,   # drop to 2 if you hit OOM
)
# Out:
# Processing pages [1, 2, 3] (carry_over=[])...
# Processing pages [4, 5, 6] (carry_over=[])...
# Processing pages [7, 8, 9] (carry_over=[])...
# Processing pages [10, 11, 12] (carry_over=[])...
#
# Done in 241.4s. 12 question/part chunks -> /content/drive/MyDrive/learningagentpastpapers/9709_m26_qp_42
